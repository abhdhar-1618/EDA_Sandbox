# %% [markdown]
# # Resources
# ## Instructor Name:- Mark Keith
# ## Resource Link:- [Youtube](https://youtu.be/RqU08Ufh_Js?si=LsBWApSRxRzIBtbp)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#from scipy import stats
import statistics as stat
import scipy.stats as stats

# %%
# Creating a list below

edu_PartialHighSchool = [30000,10000,10000,20000,70000,30000,10000,20000,10000,30000]
edu_HighSchool = [20000,30000,60000,20000,40000,60000,60000]
edu_PartialCollege = [60000,40000,30000,130000,60000,40000]
edu_Bachelors = [40000,20000,90000,120000,60000,130000,20000,100000,80000,30000,100000,120000]
edu_Graduate = [160000,50000,80000,30000,40000,80000,130000,100000,130000,50000,130000]

print('Partial High School: ' + str(int(stat.mean(edu_PartialHighSchool))))
print('High School: ' + str(int(stat.mean(edu_HighSchool))))
print('Partial College: ' + str(int(stat.mean(edu_PartialCollege))))
print('Bachelors: ' + str(int(stat.mean(edu_Bachelors))))
print('Graduate: ' + str(int(stat.mean(edu_Graduate))))
# Out:
# Partial High School: 24000
# High School: 41428
# Partial College: 60000
# Bachelors: 75833
# Graduate: 89090

# %%
t, p = stats.ttest_ind(edu_PartialHighSchool, edu_HighSchool)
print(f't-value: {t}')
print(f'p-value: {p}')
# Out:
# t-value: -1.9131753750607223
# p-value: 0.07500898731578687

# %%
import seaborn as sns
sns.distplot(edu_PartialHighSchool, label="Partial High School")
sns.distplot(edu_HighSchool, label="High School");
# Out:
# C:\Users\Abhik\AppData\Local\Temp\ipykernel_29764\1151236051.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_PartialHighSchool, label="Partial High School")
# C:\Users\Abhik\AppData\Local\Temp\ipykernel_29764\1151236051.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_HighSchool, label="High School");

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(edu_PartialHighSchool, label="Partial High School")
sns.distplot(edu_HighSchool, label="High School");
sns.distplot(edu_PartialCollege, label="Partial College");
sns.distplot(edu_Bachelors, label="Bachelors");
sns.distplot(edu_Graduate, label="Graduate");
plt.legend();
# Out:
# C:\Users\Abhik\AppData\Local\Temp\ipykernel_29764\381264662.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_PartialHighSchool, label="Partial High School")
# C:\Users\Abhik\AppData\Local\Temp\ipykernel_29764\381264662.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_HighSchool, label="High School");
# C:\Users\Abhik\AppData\Local\Temp\ipykernel_29764\381264662.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_PartialCollege, label="Partial College");
# C:\Users\Abhik\AppData\Local\Temp\ipykernel_29764\381264662.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_Bachelors, label="Bachelors");
# C:\Users\Abhik\AppData\Local\Temp\ipykernel_29764\381264662.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_Graduate, label="Graduate");

# %%
stats.f_oneway(edu_Bachelors, edu_Graduate, edu_HighSchool, edu_PartialCollege, edu_PartialHighSchool)
# Out:
# F_onewayResult(statistic=5.778065095961635, pvalue=0.0008781084858501968)

# %%
f,p = stats.f_oneway(edu_Bachelors, edu_Graduate, edu_HighSchool, edu_PartialCollege, edu_PartialHighSchool)

print(f'f-value: {f}')
print(f'p-value: {p}')
# Out:
# f-value: 5.778065095961635
# p-value: 0.0008781084858501968

# %%
sns.histplot(data=df, x="charges", hue="sex", kde=True);

# %%
sns.histplot(data=df, x="charges", hue="smoker", kde=True);

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
sns.histplot(data=df, x="smoker", hue="sex", kde=True);

# %%
smoker_y = df[df['smoker'] == 'yes']
smoker_n = df[df['smoker'] == 'no']

stats.ttest_ind(smoker_y['charges'], smoker_n['charges'])
# Out:
# Ttest_indResult(statistic=46.66492117272371, pvalue=8.271435842179102e-283)

# %%
feature = 'smoker'
label = 'charges'

groups = df[feature].unique()
print(groups)
# Out:
# ['yes' 'no']

# %%
feature = 'smoker'
label = 'charges'

groups = df[feature].unique()
for group in groups:
    print(group)
# Out:
# yes
# no

# %%
feature = 'smoker'
label = 'charges'

groups = df[feature].unique()
for group in groups:
  print(df[df[feature] == group][label])
# Out:
# 0       16884.92400
# 11      27808.72510
# 14      39611.75770
# 19      36837.46700
# 23      37701.87680
#            ...
# 1313    36397.57600
# 1314    18765.87545
# 1321    28101.33305
# 1323    43896.37630
# 1337    29141.36030
# Name: charges, Length: 274, dtype: float64
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
# 5        3756.62160
#            ...
# 1332    11411.68500
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# Name: charges, Length: 1064, dtype: float64

# %%
feature = 'smoker'
label = 'charges'

groups = df[feature].unique()
grouped_values = []
for group in groups:
  grouped_values.append(df[df[feature] == group][label])

grouped_values
# Out:
# [0       16884.92400
#  11      27808.72510
#  14      39611.75770
#  19      36837.46700
#  23      37701.87680
#             ...
#  1313    36397.57600
#  1314    18765.87545
#  1321    28101.33305
#  1323    43896.37630
#  1337    29141.36030
#  Name: charges, Length: 274, dtype: float64,
#  1        1725.55230
#  2        4449.46200
#  3       21984.47061
#  4        3866.85520
#  5        3756.62160
#             ...
#  1332    11411.68500
#  1333    10600.54830
#  1334     2205.98080
#  1335     1629.83350
#  1336     2007.94500
#  Name: charges, Length: 1064, dtype: float64]

# %%
feature = 'smoker'
label = 'charges'

groups = df[feature].unique()
grouped_values = []
for group in groups:
  grouped_values.append(df[df[feature] == group][label])

grouped_values

stats.f_oneway(*grouped_values)
# Out:
# F_onewayResult(statistic=2177.614868056519, pvalue=8.271435842182967e-283)

# %%
feature = 'sex'
label = 'charges'

groups = df[feature].unique()
grouped_values = []
for group in groups:
  grouped_values.append(df[df[feature] == group][label])

grouped_values

stats.f_oneway(*grouped_values)
# Out:
# F_onewayResult(statistic=4.3997016974374565, pvalue=0.03613272100596256)

# %%
def anova(feature, label):
  groups = df[feature].unique()
  grouped_values = []
  for group in groups:
    grouped_values.append(df[df[feature] == group][label])
  return stats.f_oneway(*grouped_values)

# %%
anova('smoker', 'charges')
# Out:
# F_onewayResult(statistic=2177.614868056519, pvalue=8.271435842182967e-283)

# %% [markdown]
# ## Session Concluded
# (Not Pushed to github)
